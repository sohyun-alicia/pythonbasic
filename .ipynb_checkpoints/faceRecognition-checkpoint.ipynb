# %%
# 필요한 모듈 설치
# pillow : 사진 관련 모듈
# requests : 인터넷 연결 관련 모듈

# !pip install pillow    
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\82108\anaconda3\lib\site-packages (7.0.0)
# Requirement already satisfied: requests in c:\users\82108\anaconda3\lib\site-packages (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\82108\anaconda3\lib\site-packages (from requests) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\82108\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82108\anaconda3\lib\site-packages (from requests) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\82108\anaconda3\lib\site-packages (from requests) (2.8)

# %%
import matplotlib.pyplot as plt    # 그림관련 
import matplotlib.image as mpimg    # 사진관련 

# 생략 가능 : 웹페이지 상의 그림 표현
# %matplotlib inline

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 사진 한장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.340089
#             }
#         }
#     ]
# }

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/face"
files = {'image':open('face1.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 사진 한장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "errorMessage": "/v1/face : Malformed URL (잘못된 형식의 호출 URL입니다.)",
#     "errorCode": "061"
# }

# %%
img = mpimg.imread('sohyun.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('sohyun.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 2160,
#             "height": 2880
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "조우리",
#                 "confidence": 0.674363
#             }
#         }
#     ]
# }

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('sohyun.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 2160,
#             "height": 2880
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 818,
#                 "y": 742,
#                 "width": 855,
#                 "height": 855
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 1045,
#                     "y": 921
#                 },
#                 "rightEye": {
#                     "x": 1452,
#                     "y": 938
#                 },
#                 "nose": {
#                     "x": 1267,
#                     "y": 1191
#                 },
#                 "leftMouth": {
#                     "x": 1057,
#                     "y": 1341
#                 },
#                 "rightMouth": {
#                     "x": 1369,
#                     "y": 1351
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999983
#             },
#             "age": {
#                 "value": "22~26",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.99741
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.99925
#             }
#         }
#     ]
# }

# %%
img = mpimg.imread('hong1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('hong1.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 480,
#             "height": 640
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "임화영",
#                 "confidence": 0.397494
#             }
#         }
#     ]
# }

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('hyunda.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 1932,
#             "height": 2576
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 594,
#                 "y": 514,
#                 "width": 916,
#                 "height": 916
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 797,
#                     "y": 727
#                 },
#                 "rightEye": {
#                     "x": 1259,
#                     "y": 730
#                 },
#                 "nose": {
#                     "x": 985,
#                     "y": 1012
#                 },
#                 "leftMouth": {
#                     "x": 834,
#                     "y": 1195
#                 },
#                 "rightMouth": {
#                     "x": 1175,
#                     "y": 1209
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999893
#             },
#             "age": {
#                 "value": "19~23",
#                 "confidence": 0.590869
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.997583
#             }
#         },
#         {
#             "roi": {
#                 "x": 36,
#                 "y": 1121,
#                 "width": 34,
#                 "height": 34
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.462605
#             },
#             "age": {
#                 "value": "65~69",
#                 "confidence": 0.152243
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.970684
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.96336
#             }
#         },
#         {
#             "roi": {
#                 "x": 28,
#                 "y": 921,
#                 "width": 37,
#                 "height": 37
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.6612
#             },
#             "age": {
#                 "value": "26~30",
#                 "confidence": 0.771201
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941892
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.999081
#             }
#         },
#         {
#             "roi": {
#                 "x": 36,
#                 "y": 951,
#                 "width": 36,
#                 "height": 36
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.976793
#             },
#             "age": {
#                 "value": "26~30",
#                 "confidence": 0.00873049
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.995335
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.979259
#             }
#         }
#     ]
# }

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 사진 한장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999797
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.870835
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941112
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.990651
#             }
#         },
#         {
#             "roi": {
#                 "x": 268,
#                 "y": 71,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999965
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.870391
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.996715
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.777422
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 144,
#                 "width": 26,
#                 "height": 26
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.882768
#             },
#             "age": {
#                 "value": "5~9",
#                 "confidence": 0.941211
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.989725
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.895872
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 153,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 138,
#                     "y": 159
#                 },
#                 "rightEye": {
#                     "x": 148,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 164
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 168
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.902951
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.0996041
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.897915
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.96725
#             }
#         }
#     ]
# }

# %% [markdown]
# # 기본 문법 학습

# %%
# dict형과 json에 대해...

dict = {'Name':'pinkwink', 
        'Age':'None', 
        'Class':['beginner','blog']}
dict
# Out:
# {'Name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('Age', 'nothing')
# Out:
# 'None'

# %%
dict.get('Room', 'nothing')
# Out:
# 'nothing'

# %%
# =====================================
# json (Java Script Objecgt Notation)

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'date':'2019-03-01', 'log':True},
        {'date':'2019-03-02', 'log':False}
    ]
}

# %%
import json
json_test = json.dumps(customer, indent = 4, ensure_ascii=False)    # ensure_ascii=False : 숫자가 깨지는걸 방지
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %% [markdown]
# # 사진 위에 정보 표시하기

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 사진 한장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999998
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.441697
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.991977
#             }
#         }
#     ]
# }

# %%
print(response.text)    # 자르기 전 내용
# Out:
# {"info":{"size":{"width":680,"height":400},"faceCount":1},"faces":[{"roi":{"x":272,"y":98,"width":113,"height":113},"landmark":{"leftEye":{"x":298,"y":124},"rightEye":{"x":350,"y":129},"nose":{"x":320,"y":157},"leftMouth":{"x":297,"y":182},"rightMouth":{"x":343,"y":186}},"gender":{"value":"male","confidence":0.999998},"age":{"value":"30~34","confidence":0.441697},"emotion":{"value":"neutral","confidence":1.0},"pose":{"value":"frontal_face","confidence":0.991977}}]}

# %%
parsed.keys()    # response 내용을 잘라줌
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces'][0]    # 첫번째 사람의 얼굴 정보
# Out:
# {'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#  'landmark': {'leftEye': {'x': 298, 'y': 124},
#   'rightEye': {'x': 350, 'y': 129},
#   'nose': {'x': 320, 'y': 157},
#   'leftMouth': {'x': 297, 'y': 182},
#   'rightMouth': {'x': 343, 'y': 186}},
#  'gender': {'value': 'male', 'confidence': 0.999998},
#  'age': {'value': '30~34', 'confidence': 0.441697},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.991977}}

# %%
parsed['faces'][0]['roi']    # 얼굴의 위치값
# Out:
# {'x': 272, 'y': 98, 'width': 113, 'height': 113}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999998}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '30~34', 'confidence': 0.441697}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
print(x)
print(y)
print(w)
print(h)
print(gender)
print(gen_confi)
# Out:
# 272
# 98
# 113
# 113
# male
# 0.999998

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " : " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999998
# neutral : 1.0
# 30~34 : 0.441697

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig, ax = plt.subplots(figsize = (10, 10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5, 
                             edgecolor = 'r', 
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap = True, fontsize = 17, color = 'white')
plt.show()

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests # 인터넷 연결

client_id = "F3bZ6uaJDXRGC9e3mmGe"
client_secret = "6X1MQxss24"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url,files = files, headers = headers)

# %%
import json    # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 사진 한장의 최대 크기는 2MB로 네이버에서 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999797
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.870835
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941112
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.990651
#             }
#         },
#         {
#             "roi": {
#                 "x": 268,
#                 "y": 71,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999965
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.870391
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.996715
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.777422
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 144,
#                 "width": 26,
#                 "height": 26
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.882768
#             },
#             "age": {
#                 "value": "5~9",
#                 "confidence": 0.941211
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.989725
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.895872
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 153,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 138,
#                     "y": 159
#                 },
#                 "rightEye": {
#                     "x": 148,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 164
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 168
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.902951
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.0996041
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.897915
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.96725
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 2, 
                             edgecolor = 'w', 
                             facecolor = 'none')
    ax.add_patch(rect_face)
    
    annotation = gender + " : " + str(round(gen_confi,2)*100)+'%' + '\n' + emotion + " : " + str(round(emo_confi,2)*100)+'%' + '\n' + age + " : " + str(round(age_confi,2)*100)+'%'
    plt.text(x-15, y-20, annotation, wrap=True, fontsize=6, color = 'black')
